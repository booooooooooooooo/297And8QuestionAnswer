# %%
import json
import matplotlib.pyplot as plt
import numpy as np

# %%
def draw(stat1_file):
    
    with open(stat1_file) as f:
        stat1 = json.load(f)
        
    print stat1.keys()
    print stat1["config"]
    print stat1["best_graph"]
    print stat1["test_stat"]
    print stat1["train_stat"][0].keys()
    
    batch_loss = [float (batch["batch_loss"]) for batch in stat1["train_stat"]]

    train_loss = [float (batch["train_loss"]) for batch in stat1["train_stat"]]
    train_em = [float (batch["train_em"]) for batch in stat1["train_stat"]]
    train_f1 = [float (batch["train_f1"]) for batch in stat1["train_stat"]]
    valid_loss = [float (batch["valid_loss"]) for batch in stat1["train_stat"]]
    valid_em = [float (batch["valid_em"]) for batch in stat1["train_stat"]]
    valid_f1 = [float (batch["valid_f1"]) for batch in stat1["train_stat"]]

    plt.subplot(211)
    plt.plot(batch_loss, label='batch loss')
    plt.plot(train_loss, label = "sample train loss")
    plt.plot(valid_loss, label = "sample valid loss")
    
    plt.subplot(212)
    plt.plot(train_em, label = "sample train em")
    plt.plot(train_f1, label = "sample train f1")
    plt.plot(valid_em, label = "sample valid em")
    plt.plot(valid_f1, label = "sample valid f1")

    plt.xlabel('# (100 mini batches)')

    plt.title(stat1["config"]["arch"])

    plt.legend()

    plt.show()

# %%
stat1_file = "./output/Stat-March-09-2018-02-06-22"
draw(stat1_file)
# Out:
# [u'test_stat', u'best_graph', u'config', u'train_stat']
# {u'n_epoch': 5, u'embed_size': 100, u'pass_max_length': 400, u'reg_scale': 0.001, u'batch_size': 32, u'sample_size': 200, u'clip_norm': 10, u'lr': 0.002, u'num_units': 64, u'ques_max_length': 30, u'arch': u'match'}
# {u'graph': u'graphes/March-09-2018-10-56-59', u'score': u'0.312808785529'}
# {u'em': u'0.12497840235', u'loss': u'3.16323014166', u'predicted_ans_file': u'/output/predict_test_answers-March-09-2018-02-06-21', u'f1': u'0.2469369555'}
# [u'valid_loss', u'batch_loss', u'train_em', u'valid_f1', u'train_loss', u'batch', u'sample_size', u'epoch', u'valid_em', u'graph_file', u'batch_grad_norm', u'train_f1']

# %%
stat2_file = "./output/Stat-March-09-2018-11-13-35"
draw(stat2_file)
# Out:
# [u'test_stat', u'best_graph', u'config', u'train_stat']
# {u'n_epoch': 1, u'embed_size': 100, u'pass_max_length': 400, u'reg_scale': 0.001, u'batch_size': 32, u'sample_size': 200, u'clip_norm': 10, u'lr': 0.002, u'num_units': 64, u'ques_max_length': 30, u'arch': u'r_net'}
# {u'graph': u'graphes/March-09-2018-08-59-31', u'score': u'0.217056097906'}
# {u'em': u'0.12497840235', u'loss': u'3.42679321678', u'predicted_ans_file': u'/output/predict_test_answers-March-09-2018-11-13-35', u'f1': u'0.18927061228'}
# [u'valid_loss', u'batch_loss', u'train_em', u'valid_f1', u'train_loss', u'batch', u'sample_size', u'epoch', u'valid_em', u'graph_file', u'batch_grad_norm', u'train_f1']

# %%
stat3_file = "./output/Stat-March-10-2018-04-54-14"
draw(stat3_file)
# Out:
# [u'test_stat', u'best_graph', u'config', u'train_stat']
# {u'n_epoch': 1, u'embed_size': 100, u'pass_max_length': 400, u'reg_scale': 0.001, u'batch_size': 32, u'sample_size': 200, u'clip_norm': 10, u'lr': 0.002, u'num_units': 64, u'ques_max_length': 30, u'arch': u'match_simple'}
# {u'graph': u'graphes/March-10-2018-04-23-39', u'score': u'0.201344365312'}
# {u'em': u'0.0937338017624', u'loss': u'3.35023113048', u'predicted_ans_file': u'/output/predict_test_answers-March-10-2018-04-54-14', u'f1': u'0.190105198823'}
# [u'valid_loss', u'batch_loss', u'train_em', u'valid_f1', u'train_loss', u'batch', u'sample_size', u'epoch', u'valid_em', u'graph_file', u'batch_grad_norm', u'train_f1']

# %%
# plot a line, implicitly creating a subplot(111)
plt.plot([1,2,3])
# now create a subplot which represents the top plot of a grid
# with 2 rows and 1 column. Since this subplot will overlap the
# first, the plot (and its axes) previously created, will be removed
plt.subplot(211)
plt.plot(range(12))
plt.subplot(212, facecolor='y') # creates 2nd subplot with yellow background
