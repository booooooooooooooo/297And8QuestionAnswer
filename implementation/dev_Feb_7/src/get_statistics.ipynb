# %%
import nltk
import json
from tqdm import tqdm
import os
import sys
import argparse
import pickle
import random

import matplotlib.pyplot as plt

from preprocess import Preprocessor

# %%
preprocessor = Preprocessor()
# preprocessor.analyze("../data/data_json/train.json")
# preprocessor.analyze("../data/data_json/valid.json")
pass_lengths, ques_lengths = preprocessor.analyze("../data/data_json/test.json")

# plt.plot(pass_lengths)
# plt.plot(ques_lengths)
# Out:
# Analyzing ../data/data_json/test.json: 100%|██████████| 48/48 [00:04<00:00, 11.57it/s]
# How many (passage, question, answer) tuples : 34726
# pass_max_length: 700
# pass_ave_length: 142
# ques_max_length: 34
# ques_ave_length :11
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-9a912b69c7a2> in <module>()
#       2 # preprocessor.analyze("../data/data_json/train.json")
#       3 # preprocessor.analyze("../data/data_json/valid.json")
# ----> 4 pass_lengths, ques_lengths = preprocessor.analyze("../data/data_json/test.json")
#       5
#       6 # plt.plot(pass_lengths)
#
# TypeError: 'NoneType' object is not iterable
